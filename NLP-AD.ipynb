# %%
import pandas as pd

# %%
data=pd.read_csv('https://raw.githubusercontent.com/singhrau0/Big-Data-Preprocessing/refs/heads/main/youtubesample.csv')

# %%
data
# Out:
#          video_id trending_date  \
# 0     m8Dqg8iz5Fo      18.09.05
# 1     2yCp-Dj5-7c      17.16.12
# 2     H00djJq68VE      17.27.12
# 3     oTObwUiXdYY      17.19.11
# 4     yvicqMrAHvQ      18.05.02
# ...           ...           ...
# 4995  bqFjyo7I8fY      18.01.03
# 4996  K0u_kAWLJOA      18.25.01
# 4997  XGd1dq1BatM      18.19.03
# 4998  vGTTSdrV37U      18.04.04
# 4999  DkeiKbqa02g      18.22.05
#
#                                                   title  \
# 0     MY INSTAGRAM FOLLOWERS PICK MY FULL FACE OF MA...
# 1     Does Tiffany Haddish Think NeNe Leakes Is Funn...
# 2     Panettone (Italian Christmas Bread) - Food Wishes
# 3     7.3 Magnitude Earthquake Along Iraq-Iran Borde...
# 4               Turkish Airlines - 5 Senses with Dr. Oz
# ...                                                 ...
# 4995          Red Velvet 레드벨벳 '봐 (Look)' Dance Practice
# 4996                   God of War – Story Trailer | PS4
# 4997  Halsey - Alone (Audio) ft. Big Sean, Stefflon Don
# ...

# %%
data.head()
# Out:
#       video_id trending_date  \
# 0  m8Dqg8iz5Fo      18.09.05
# 1  2yCp-Dj5-7c      17.16.12
# 2  H00djJq68VE      17.27.12
# 3  oTObwUiXdYY      17.19.11
# 4  yvicqMrAHvQ      18.05.02
#
#                                                title  \
# 0  MY INSTAGRAM FOLLOWERS PICK MY FULL FACE OF MA...
# 1  Does Tiffany Haddish Think NeNe Leakes Is Funn...
# 2  Panettone (Italian Christmas Bread) - Food Wishes
# 3  7.3 Magnitude Earthquake Along Iraq-Iran Borde...
# 4            Turkish Airlines - 5 Senses with Dr. Oz
#
#                              channel_title  category_id  \
# 0                              Sylvia Gani           26
# 1  Watch What Happens Live with Andy Cohen           24
# 2                              Food Wishes           26
# 3                                     TIME           25
# 4                         Turkish Airlines           19
#
#                publish_time  \
# 0  2018-04-30T00:18:19.000Z
# 1  2017-12-11T04:29:53.000Z
# ...

# %%
data.tail()
# Out:
#          video_id trending_date  \
# 4995  bqFjyo7I8fY      18.01.03
# 4996  K0u_kAWLJOA      18.25.01
# 4997  XGd1dq1BatM      18.19.03
# 4998  vGTTSdrV37U      18.04.04
# 4999  DkeiKbqa02g      18.22.05
#
#                                                   title     channel_title  \
# 4995          Red Velvet 레드벨벳 '봐 (Look)' Dance Practice            SMTOWN
# 4996                   God of War – Story Trailer | PS4       PlayStation
# 4997  Halsey - Alone (Audio) ft. Big Sean, Stefflon Don        HalseyVEVO
# 4998  Camila Cabello WINS Favorite Breakout Artist 🎤...       Nickelodeon
# 4999  Calvin Harris, Dua Lipa - One Kiss (Official V...  CalvinHarrisVEVO
#
#       category_id              publish_time  \
# 4995           10  2018-02-22T03:00:00.000Z
# 4996           20  2018-01-23T16:00:02.000Z
# 4997           10  2018-03-15T22:00:01.000Z
# 4998           24  2018-03-25T01:22:15.000Z
# 4999           10  2018-05-02T23:01:00.000Z
#
# ...

# %%
df=data.sample(30)
df
# Out:
#          video_id trending_date  \
# 83    -e-xXN-tcFU      18.12.05
# 1701  cWGWYAhLuAQ      18.15.02
# 463   g0K5QoEj7FQ      17.17.11
# 2109  96bpvMCfBfo      18.12.02
# 2951  EqeIRzY7hIU      18.30.05
# 4647  nk-_RJcWd4M      18.04.01
# 4051  8Y5-GI9hYcI      18.07.05
# 3594  trW9rxpSBxA      18.23.01
# 989   MFWF9dU5Zc0      17.21.12
# 1360  SwqUpegUT2Q      18.19.04
# 3311  vYb4_ARPNfo      18.24.05
# 3364  SagsqxiVStM      18.13.01
# 1168  irHqI9fUc4I      18.11.06
# 3132  305ryPvU6A8      18.12.03
# 701   hlb3gGNBHFE      18.13.03
# 3692  WpTjFhA09kQ      18.03.02
# 3633  WdOGSNQP9b4      18.08.03
# 514   ySy8mcceTno      18.04.01
# 4328  hz7ukDjuq4w      17.16.11
# 1591  xVU8nEIsapY      18.01.05
# 2523  trcditUaQJg      18.26.04
# 2256  PCTVL5oKlik      18.21.02
# 1058  YI3tsmFsrOg      18.20.05
# 3500  OKgUiBOpsZ4      18.20.01
# 898   qaivW5joQrk      17.05.12
# 3231  SlbY1tGARUA      18.08.02
# 1692  NtFe5PM87BU      18.16.02
# 3829  tpa4kp4lK60      18.03.05
# ...

# %%
df.iloc[1:9:1]
# Out:
#          video_id trending_date  \
# 1701  cWGWYAhLuAQ      18.15.02
# 463   g0K5QoEj7FQ      17.17.11
# 2109  96bpvMCfBfo      18.12.02
# 2951  EqeIRzY7hIU      18.30.05
# 4647  nk-_RJcWd4M      18.04.01
# 4051  8Y5-GI9hYcI      18.07.05
# 3594  trW9rxpSBxA      18.23.01
# 989   MFWF9dU5Zc0      17.21.12
#
#                                                   title  \
# 1701  This is what happens when you don't sleep in |...
# 463   Does Gwen Stefani Know If Blake Shelton Is Peo...
# 2109  Calum Scott, Leona Lewis - You Are The Reason ...
# 2951                  6 Cheese Gadgets put to the Test!
# 4647  Clownfish That Look like Cows?! (Also, Address...
# 4051  Abraham Mateo, Yandel, Jennifer Lopez - Se Aca...
# 3594  Worlds Highest Basketball Shot 200m (660 feet)...
# 989                    OCEAN'S 8 - Official 1st Trailer
#
#               channel_title  category_id              publish_time  \
# 1701             Will Smith           24  2018-02-07T17:00:03.000Z
# ...

# %%
#df.loc[1:9:1]

# %%
data.loc[1:9:1]
# Out:
#       video_id trending_date  \
# 1  2yCp-Dj5-7c      17.16.12
# 2  H00djJq68VE      17.27.12
# 3  oTObwUiXdYY      17.19.11
# 4  yvicqMrAHvQ      18.05.02
# 5  qDAxDcjgn-8      17.18.11
# 6  kton-qrKNLc      18.08.03
# 7  oRArmtMA9AI      18.15.03
# 8  84p7f-Rh-RY      17.21.12
# 9  Biex1XR_mpo      18.24.03
#
#                                                title  \
# 1  Does Tiffany Haddish Think NeNe Leakes Is Funn...
# 2  Panettone (Italian Christmas Bread) - Food Wishes
# 3  7.3 Magnitude Earthquake Along Iraq-Iran Borde...
# 4            Turkish Airlines - 5 Senses with Dr. Oz
# 5             Taylor Swift - Reputation ALBUM REVIEW
# 6                        Meghan Trainor - No Excuses
# 7            Marshmello - FLY (Official Music Video)
# 8  Kate Winslet On Working With Woody Allen | Los...
# 9             50 Mums | 50 Kids | 1 Extra Chromosome
#
#                              channel_title  category_id  \
# 1  Watch What Happens Live with Andy Cohen           24
# ...

# %%
df.loc[1701:4051:2]
# Out:
#          video_id trending_date  \
# 1701  cWGWYAhLuAQ      18.15.02
# 2109  96bpvMCfBfo      18.12.02
# 4647  nk-_RJcWd4M      18.04.01
#
#                                                   title       channel_title  \
# 1701  This is what happens when you don't sleep in |...          Will Smith
# 2109  Calum Scott, Leona Lewis - You Are The Reason ...      CalumScottVEVO
# 4647  Clownfish That Look like Cows?! (Also, Address...  Taylor Nicole Dean
#
#       category_id              publish_time  \
# 1701           24  2018-02-07T17:00:03.000Z
# 2109           10  2018-02-08T05:00:01.000Z
# 4647           15  2017-12-31T00:08:18.000Z
#
#                                                    tags   views  likes  \
# 1701  will smith|"will"|"smith"|"smiths"|"willsmith"...  952205  54359
# 2109  calum scott|"leona lewis"|"you are the reason"...  445636  23512
# 4647  taylor nicole dean|"taylor dean"|"pets"|"cowfi...  406803  24276
#
# ...

# %%
data['video_id']
# Out:
# 0       m8Dqg8iz5Fo
# 1       2yCp-Dj5-7c
# 2       H00djJq68VE
# 3       oTObwUiXdYY
# 4       yvicqMrAHvQ
#            ...
# 4995    bqFjyo7I8fY
# 4996    K0u_kAWLJOA
# 4997    XGd1dq1BatM
# 4998    vGTTSdrV37U
# 4999    DkeiKbqa02g
# Name: video_id, Length: 5000, dtype: object

# %%
data[data['views'] > 400000]
# Out:
#          video_id trending_date  \
# 0     m8Dqg8iz5Fo      18.09.05
# 4     yvicqMrAHvQ      18.05.02
# 6     kton-qrKNLc      18.08.03
# 7     oRArmtMA9AI      18.15.03
# 9     Biex1XR_mpo      18.24.03
# ...           ...           ...
# 4995  bqFjyo7I8fY      18.01.03
# 4996  K0u_kAWLJOA      18.25.01
# 4997  XGd1dq1BatM      18.19.03
# 4998  vGTTSdrV37U      18.04.04
# 4999  DkeiKbqa02g      18.22.05
#
#                                                   title  \
# 0     MY INSTAGRAM FOLLOWERS PICK MY FULL FACE OF MA...
# 4               Turkish Airlines - 5 Senses with Dr. Oz
# 6                           Meghan Trainor - No Excuses
# 7               Marshmello - FLY (Official Music Video)
# 9                50 Mums | 50 Kids | 1 Extra Chromosome
# ...                                                 ...
# 4995          Red Velvet 레드벨벳 '봐 (Look)' Dance Practice
# 4996                   God of War – Story Trailer | PS4
# 4997  Halsey - Alone (Audio) ft. Big Sean, Stefflon Don
# ...

# %%
data[data['views'] > 500000]
# Out:
#          video_id trending_date  \
# 0     m8Dqg8iz5Fo      18.09.05
# 4     yvicqMrAHvQ      18.05.02
# 6     kton-qrKNLc      18.08.03
# 7     oRArmtMA9AI      18.15.03
# 9     Biex1XR_mpo      18.24.03
# ...           ...           ...
# 4995  bqFjyo7I8fY      18.01.03
# 4996  K0u_kAWLJOA      18.25.01
# 4997  XGd1dq1BatM      18.19.03
# 4998  vGTTSdrV37U      18.04.04
# 4999  DkeiKbqa02g      18.22.05
#
#                                                   title  \
# 0     MY INSTAGRAM FOLLOWERS PICK MY FULL FACE OF MA...
# 4               Turkish Airlines - 5 Senses with Dr. Oz
# 6                           Meghan Trainor - No Excuses
# 7               Marshmello - FLY (Official Music Video)
# 9                50 Mums | 50 Kids | 1 Extra Chromosome
# ...                                                 ...
# 4995          Red Velvet 레드벨벳 '봐 (Look)' Dance Practice
# 4996                   God of War – Story Trailer | PS4
# 4997  Halsey - Alone (Audio) ft. Big Sean, Stefflon Don
# ...

# %%
data['comment_count'] > 5000
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995     True
# 4996     True
# 4997    False
# 4998    False
# 4999     True
# Name: comment_count, Length: 5000, dtype: bool

# %%
data[data['comment_count'] > 5000]
# Out:
#          video_id trending_date  \
# 6     kton-qrKNLc      18.08.03
# 7     oRArmtMA9AI      18.15.03
# 10    RQm0nKoODo4      18.13.03
# 17    QBL8IRJ5yHU      18.04.06
# 18    wW4JB9tjlik      18.10.06
# ...           ...           ...
# 4977  uVcvhKTVZ8g      18.04.05
# 4980  tfREC-AkX20      18.14.04
# 4995  bqFjyo7I8fY      18.01.03
# 4996  K0u_kAWLJOA      18.25.01
# 4999  DkeiKbqa02g      18.22.05
#
#                                                   title      channel_title  \
# 6                           Meghan Trainor - No Excuses  MeghanTrainorVEVO
# 7               Marshmello - FLY (Official Music Video)         Marshmello
# 10             Take On Me in 20 Styles ft. Seth Everman   Ten Second Songs
# 17    Why I'm So Scared (being myself and crying too...      grav3yardgirl
# 18    24 HOUR BOX FORT PRISON ESCAPE ROOM!! 📦🚔 UNDER...          Papa Jake
# ...                                                 ...                ...
# ...

# %%
import nltk

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
import pandas as pd

# %%
# !kaggle datasets download -d abdallahwagih/spam-emails
# !unzip spam-emails.zip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/abdallahwagih/spam-emails
# License(s): apache-2.0
# ...
#   0% 0.00/207k [00:00<?, ?B/s]
# 100% 207k/207k [00:00<00:00, 76.0MB/s]
# Archive:  spam-emails.zip
#   inflating: spam.csv

# %%
df=pd.read_csv("spam.csv")

# %%
df.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
#read the data from index position 3 to 10
data=df.iloc[3:10]
data
# Out:
#   Category                                            Message
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# 5     spam  FreeMsg Hey there darling it's been 3 week's n...
# 6      ham  Even my brother is not like to speak with me. ...
# 7      ham  As per your request 'Melle Melle (Oru Minnamin...
# 8     spam  WINNER!! As a valued network customer you have...
# 9     spam  Had your mobile 11 months or more? U R entitle...

# %%
data.iloc[0,0]
# Out:
# 'ham'

# %%
data.iloc[0,1]
# Out:
# 'U dun say so early hor... U c already then say...'

# %%
#Starting data mining
x=data.iloc[0,1]

# %%
x
# Out:
# 'U dun say so early hor... U c already then say...'

# %%
word_tokenize(x)
# Out:
# ['U',
#  'dun',
#  'say',
#  'so',
#  'early',
#  'hor',
#  '...',
#  'U',
#  'c',
#  'already',
#  'then',
#  'say',
#  '...']

# %%
[word_tokenize(x) for x in data['Message']]
# Out:
# [['U',
#   'dun',
#   'say',
#   'so',
#   'early',
#   'hor',
#   '...',
#   'U',
#   'c',
#   'already',
#   'then',
#   'say',
#   '...'],
#  ['Nah',
#   'I',
#   'do',
#   "n't",
#   'think',
#   'he',
#   'goes',
#   'to',
#   'usf',
#   ',',
#   'he',
#   'lives',
#   'around',
#   'here',
#   'though'],
#  ['FreeMsg',
#   'Hey',
#   'there',
#   'darling',
#   'it',
#   "'s",
#   'been',
#   '3',
#   'week',
#   "'s",
#   'now',
#   'and',
#   'no',
#   'word',
#   'back',
#   '!',
#   'I',
#   "'d",
#   'like',
#   'some',
#   'fun',
#   'you',
#   'up',
#   'for',
#   'it',
#   'still',
#   '?',
#   'Tb',
#   'ok',
#   '!',
#   'XxX',
#   'std',
#   'chgs',
#   'to',
#   'send',
#   ',',
#   '£1.50',
#   'to',
#   'rcv'],
#  ['Even',
#   'my',
#   'brother',
#   'is',
#   'not',
#   'like',
#   'to',
#   'speak',
#   'with',
#   'me',
#   '.',
#   'They',
#   'treat',
#   'me',
#   'like',
#   'aids',
#   'patent',
#   '.'],
#  ['As',
#   'per',
#   'your',
#   'request',
# ...

# %%
for i in data['Message']:
  print(word_tokenize(i))
# Out:
# ['U', 'dun', 'say', 'so', 'early', 'hor', '...', 'U', 'c', 'already', 'then', 'say', '...']
# ['Nah', 'I', 'do', "n't", 'think', 'he', 'goes', 'to', 'usf', ',', 'he', 'lives', 'around', 'here', 'though']
# ['FreeMsg', 'Hey', 'there', 'darling', 'it', "'s", 'been', '3', 'week', "'s", 'now', 'and', 'no', 'word', 'back', '!', 'I', "'d", 'like', 'some', 'fun', 'you', 'up', 'for', 'it', 'still', '?', 'Tb', 'ok', '!', 'XxX', 'std', 'chgs', 'to', 'send', ',', '£1.50', 'to', 'rcv']
# ['Even', 'my', 'brother', 'is', 'not', 'like', 'to', 'speak', 'with', 'me', '.', 'They', 'treat', 'me', 'like', 'aids', 'patent', '.']
# ['As', 'per', 'your', 'request', "'Melle", 'Melle', '(', 'Oru', 'Minnaminunginte', 'Nurungu', 'Vettam', ')', "'", 'has', 'been', 'set', 'as', 'your', 'callertune', 'for', 'all', 'Callers', '.', 'Press', '*', '9', 'to', 'copy', 'your', 'friends', 'Callertune']
# ...

# %%
#21-01-25 day12

# %%
#message=pd.read_csv("spam.csv")

# %%
import re

# %%
text=df['Message'][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'message'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-afbe8fd2337d> in <cell line: 0>()
# ----> 1 text=df['message'][0]
#
# ...

# %%
# Remove special characters and punctuation using regex
cleaned_text = re.sub(r'[^\w\s]', '', text)  # Removes everything except word characters and spaces
cleaned_text = re.sub(r'\s+', ' ', cleaned_text)  # Replaces multiple spaces with a single space
cleaned_text.strip()  # Removes leading/trailing whitespace
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-66f06facb55c> in <cell line: 0>()
#       1 # Remove special characters and punctuation using regex
# ...
